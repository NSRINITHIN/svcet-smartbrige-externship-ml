# %% [markdown]
# ####ASSIGNMENT-1

# %% [markdown]
# ##TASK-1
# #Create a pandas datatrame (DataFrame name as 'df) with numpy random values (4 teatures and 4 observation)

# %%
import numpy as np
import pandas as pd

# %%
data=np.random.rand(4,4)
df=pd.DataFrame(data,columns=['FEATURE1','FEATURE2','FEATURE3','FEATURE4'])#created features
df
# Out:
#    FEATURE1  FEATURE2  FEATURE3  FEATURE4
# 0  0.267690  0.857239  0.761342  0.677363
# 1  0.545596  0.648844  0.719641  0.142168
# 2  0.728579  0.465063  0.207784  0.488902
# 3  0.522336  0.147514  0.395034  0.857006

# %% [markdown]
# ##TASK-2
# ##Rename the task-1 'df dataframe column names to 'Random value 11, Random value 2' 'Random value 3 & 'Random value 4'

# %%
df.columns=['number','Range','Rad','pointvalue']#created features with custom names
df
# Out:
#      number     Range       Rad  pointvalue
# 0  0.267690  0.857239  0.761342    0.677363
# 1  0.545596  0.648844  0.719641    0.142168
# 2  0.728579  0.465063  0.207784    0.488902
# 3  0.522336  0.147514  0.395034    0.857006

# %% [markdown]
# ##TASK-3
# ## Find the descriptive statistics of the 'df dataframe.

# %%
df.describe()
# Out:
#          number     Range       Rad  pointvalue
# count  4.000000  4.000000  4.000000    4.000000
# mean   0.516050  0.529665  0.520950    0.541360
# std    0.189529  0.300955  0.265326    0.305633
# min    0.267690  0.147514  0.207784    0.142168
# 25%    0.458675  0.385675  0.348222    0.402218
# 50%    0.533966  0.556953  0.557338    0.583132
# 75%    0.591342  0.700943  0.730066    0.722274
# max    0.728579  0.857239  0.761342    0.857006

# %% [markdown]
# ##TASK-4
# ##Check for the null values in 'df and find the data type of the columns.

# %%
null_values = df.isnull().sum()
print("Null Values:\n", null_values)
# Out:
# Null Values:
#  number        0
# Range         0
# Rad           0
# pointvalue    0
# dtype: int64

# %% [markdown]
# ##TASK-5
# ##Display the "Random value 2' & Random value 3 columris with location method and index location method.

# %%
df.iloc[:,[1,2]]
# Out:
#       Range       Rad
# 0  0.857239  0.761342
# 1  0.648844  0.719641
# 2  0.465063  0.207784
# 3  0.147514  0.395034

# %%
df.loc[:,['Range','Rad']]
# Out:
#       Range       Rad
# 0  0.857239  0.761342
# 1  0.648844  0.719641
# 2  0.465063  0.207784
# 3  0.147514  0.395034
